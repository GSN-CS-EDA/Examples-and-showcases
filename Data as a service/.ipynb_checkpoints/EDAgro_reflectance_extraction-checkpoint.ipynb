# %% [markdown]
# <!--  <img width="20%" alt="EarthDaily Analytics" src="https://raw.githubusercontent.com/earthdaily/Images/main/Corporate/EarthDaily.png" style="border-radius: 15%">-->
#
# <img width="20%" alt="EarthDaily Agro" src="https://raw.githubusercontent.com/earthdaily/Images/main/Corporate/EarthDaily_Agro.png"  style="border-radius: 15%">

# %% [markdown]
# # EDAgro - Get reflectance data from Earth Data Store
# <a href="https://earthdaily.com/contact/">Give Feedback</a> | <a href="https://github.com/earthdaily">Bug report</a>

# %% [markdown]
# **Tags:** #EDS #timeseries #vegetationindex

# %% [markdown]
# **Author:** [Earthdaily Analytics](mailto:sales@earthdailyagro.com)

# %% [markdown]
# **Last update:** 2024-10-25 (Created: 2024-10-24)

# %% [markdown]
# **Description:** this notebook will guide you through steps to fetch reflectance data from EarthData Store and compute vegetation indexes maps and time series. Before using this notebook, please make sure that you successfully went through all prerequites detailled [here](https://github.com/earthdaily/Examples-and-showcases).

# %% [markdown]
# **References:**
# - [Earthdaily package](https://github.com/earthdaily/earthdaily-python-client)
# - [Earthdata Store documentation](https://earthdaily.github.io/EDA-Documentation/)
# - [Xarray as multi-dimensional object](https://docs.xarray.dev/en/stable/)

# %% [markdown]
# ## 1️⃣ Input

# %% [markdown]
# ### Import dependencies

# %%
import geopandas as gpd
import pandas as pd
import earthdaily
from matplotlib import pyplot as plt
from earthdaily import datasets, EarthDataStore
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %% [markdown]
# ### Authentication
# - `eds`: Init earthdatastore with environment variables or default credentials. Please check prerequisites>

# %%
from dotenv import load_dotenv
load_dotenv(r"C:\Users\gsn\OneDrive - EARTHDAILY\Documents\GitHub\Examples-and-showcases\Data as a service\.env")
eds = EarthDataStore()

# %% [markdown]
# ### Setup Variables
# - `geometry`: geometry on which you want to generate your datacube

# %%
geometry = 'POLYGON((-91.29142894123093 40.395442520182684,-91.28204120967882 40.395303613502904,-91.2821806845476 40.38794932129329,-91.29167570446032 40.38808007127801,-91.29142894123093 40.395442520182684))'
start_date = "2025-05-10"
end_date = "2025-07-09"
bands=["blue", "green", "red", "nir","swir16","swir22"]
collections="sentinel-2-l2a"
mask_type="native" # equal to "scl" for sentinel-2
min_clear_cover_percent=90

# %% [markdown]
# ## 2️⃣ Get Data

# %% [markdown]
# ### Get datacube

# %%
s2_datacube = eds.datacube(
    collections,
    assets=bands,
    intersects=geometry,
    datetime=[start_date, end_date],
    mask_with=mask_type,  
    clear_cover=min_clear_cover_percent,
)

# %% [markdown]
# ### Compute NDVI

# %%
 # NDVI formula
def NDVI(red,nir):
    return  ((nir - red)/(nir + red))

# %% [markdown]
# ##### NDVI images computing for all dates

# %%
dates_1=[]
NDVIs=[]
for date,cube_date in s2_datacube.groupby('time',squeeze=False):
    NDVIs.append(NDVI(cube_date.red,cube_date.nir))
    dates_1.append(date)
length = int(len(NDVIs)/3)
print(len(NDVIs))
# Out:
# 7

# %% [markdown]
# ### Compute ARVI

# %%
def ARVI(nir,red, blue):
    return((nir - (2 * red - blue))/(nir + (2 * red + blue)))

# %% [markdown]
# ##### ARVI images computing for all dates

# %%
dates_2=[]
ARVIs=[]
for date,cube_date in s2_datacube.groupby('time',squeeze=False):
    ARVIs.append(ARVI(cube_date.nir,cube_date.blue,cube_date.red))
    dates_2.append(date)
length = int(len(ARVIs)/3)
print(len(ARVIs))
# Out:
# 7

# %% [markdown]
# ## 3️⃣ Outputs

# %% [markdown]
# ### Check cloud coverage

# %%
#clear previous plots
plt.clf()

s2_datacube.clear_percent.plot.scatter(x="time")
plt.title("Percentage of clear pixels on the geometry")
plt.show()

s2_datacube.ed.plot_rgb(vmin=0, vmax=0.2, col="time", col_wrap=7)

# %% [markdown]
# ### Display NDVI
# ##### Display NDVI maps

# %%
#clear previous plots
plt.clf()

fig, axes = plt.subplots(nrows=3, ncols=length,figsize=(15, 8))
fig.suptitle(f'NDVI evolution between {str(dates_1[0])[:10]} and {str(dates_1[-1])[:10]}')
for i, ax in enumerate(axes.flat):
    ax.set_title(str(dates_1[i])[:10])
    im = ax.imshow(NDVIs[i][0],vmin=0.1,vmax=0.9,cmap='RdYlGn')
cax,kw = mpl.colorbar.make_axes(list(axes.flat))
plt.colorbar(im, cax=cax, fraction=0.046, pad=0.04)

plt.show()

# %% [markdown]
# ##### Display NDVI Times Serie

# %%
ts_1 = []
time_1 = []
for i in range(len(NDVIs)):
    y = NDVIs[i].values
    y = np.mean(y[~np.isnan(y)])
    x = NDVIs[i].time.values
    ts_1 = ts_1 + [y]
    time_1 = time_1 + [x[0]]
ts_1 = pd.DataFrame(ts_1)
time_1 = pd.DataFrame(time_1)

# %%
plt.clf()
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(10,6)
#plot
plt.scatter(time_1[0],ts_1[0], label=f'average MR NDVI') 
plt.show()

# %% [markdown]
# ### Display ARVI
# ##### Display ARVI maps

# %%
#clear previous plots
plt.clf()

fig, axes = plt.subplots(nrows=3, ncols=length,figsize=(15, 8))
fig.suptitle(f'ARVI evolution between {str(dates_2[0])[:10]} and {str(dates_2[-1])[:10]}')
for i, ax in enumerate(axes.flat):
    ax.set_title(str(dates_2[i])[:10])
    im = ax.imshow(ARVIs[i][0],vmin=0.1,vmax=0.9,cmap='RdYlGn')
cax,kw = mpl.colorbar.make_axes(list(axes.flat))
plt.colorbar(im, cax=cax, fraction=0.046, pad=0.04)

plt.show()

# %% [markdown]
# ##### Display ARVI Times Serie

# %%
ts_2 = []
time_2 = []
for i in range(len(ARVIs)):
    y = ARVIs[i].values
    y = np.mean(y[~np.isnan(y)])
    x = ARVIs[i].time.values
    ts_2 = ts_2 + [y]
    time_2 = time_2 + [x[0]]
ts_2 = pd.DataFrame(ts_2)
time_2 = pd.DataFrame(time_2)

# %%
plt.clf()
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(10,6)
#plot
plt.scatter(time_2[0],ts_2[0], label=f'average MR ARVI') 
plt.show()
